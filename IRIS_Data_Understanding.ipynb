# %% [markdown]
# # Machine Learning
#
# ### Data Understanding

# %% [markdown]
# ## IRIS Dataset
#
#    * Can be obtained from the UCI Machine Learning Repository http://archive.ics.uci.edu/ml/datasets/Iris

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
iris = pd.read_csv('iris.csv', sep=';')

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head(7)
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.size
# Out:
# 750

# %%
iris.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %%
iris['sepal length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['class'] = iris['class'].astype('category')

# %%
iris.dtypes
# Out:
# sepal length     float64
# sepal width      float64
# petal length     float64
# petal width      float64
# class           category
# dtype: object

# %%
iris['class'].unique()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
iris['class']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: category
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
iris.rename(columns={'class': 'y'})
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.rename(columns={'class': 'y'}, inplace=True)
iris
# Out:
#      sepal length  sepal width  petal length  petal width               y
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: y, Length: 150, dtype: category
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
iris['y']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: y, Length: 150, dtype: category
# Categories (3, object): ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
iris['y'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: y, dtype: int64

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['sepal length'].mean()
# Out:
# 5.843333333333334

# %%
iris.isnull()
# Out:
#      sepal length  sepal width  petal length  petal width      y
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# y               0
# dtype: int64

# %%
iris['y'].value_counts().plot(kind = 'bar', color = ['red', 'blue', 'green'])
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 7))
iris['sepal length'].hist(ax = ax[0, 0], legend=True)
iris['sepal width'].hist(ax = ax[0, 1], legend=True)
iris['petal length'].hist(ax = ax[1, 0], legend=True)
iris['petal width'].hist(ax = ax[1, 1], legend=True)
plt.show()

# %%
iris.plot(kind = 'scatter', x = 'sepal length', y = 'sepal width')
plt.show()

# %% [markdown]
# Choosing Colormaps in Matplotlib: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
encCol = iris['y'].replace({'Iris-setosa': 'yellow', 'Iris-versicolor': 'red', 'Iris-virginica': 'blue'})
iris.plot(kind = 'scatter', x = 'sepal length', y = 'sepal width', c = encCol, cmap = 'plasma')
plt.show()

# %%
encCol = iris['y'].replace({'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3})
iris.plot(kind = 'scatter', x = 'sepal length', y = 'sepal width', c = encCol, cmap = 'plasma')
plt.show()

# %%
import seaborn as sn

# %%
sn.pairplot(iris, hue = 'class')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 7))
sn.boxplot(y = 'sepal length', x = 'class', data = iris, ax = ax[0,0])
sn.boxplot(y = 'sepal width', x = 'class', data = iris, ax = ax[0,1])
sn.boxplot(y = 'petal length', x = 'class', data = iris, ax = ax[1,0])
sn.boxplot(y = 'petal width', x = 'class', data = iris, ax = ax[1,1])
plt.show()
